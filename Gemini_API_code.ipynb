# %%
# The Python SDK is a toolkit that allows you to integrate Python applications with various services and APIs

# %pip install -qU 'google-genai>=1.0.0'

# %%
from google.colab import userdata
from google import genai
from google.genai import types

GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')
client = genai.Client(api_key=GEMINI_API_KEY)

# %%
MODEL_ID = "gemini-2.5-flash"

# %%
from pydantic import BaseModel
import json
from IPython.display import Markdown

class Rating(BaseModel):
    familiarità: int
    efficacia : int

prompt = "Ti verrà presentata una lista di metafore. In una scala da 0 a 7, assegna un punteggio di familiarità e di efficacia per ciascuna metafora: " + "affetto è calore"

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=types.GenerateContentConfig(
        response_mime_type="application/json",
        response_schema=Rating,
    ),
)

print(json.dumps(json.loads(response.text), indent=4))
