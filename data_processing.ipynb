# %%
raw_MB = pd.read_csv("dataset_Metabody.xlsx - Stimuli_Metabody.csv")
raw_ME = pd.read_csv("dataset_MetaEducation.xlsx - Stimuli_MetaEducation.csv")
raw_MI = pd.read_csv("dataset_MetaImagery.xlsx - Stimuli_MetaImagery.csv")
raw_MM = pd.read_csv("dataset_MoveMe.xlsx - Stimuli_Moveme.csv")

# %%
# Processing MB dataset:

print("Info raw_MB:\n", raw_MB.info(), "\n")

for idx, row in raw_MB.iterrows():
  if row[""])


MB = raw_MB[["Metaphor", "Met_structure", "FamMetabody_Met", "SensMetabody_Met", "BodyMetabody_Met"]]
print("Head MB:\n", MB.head())
